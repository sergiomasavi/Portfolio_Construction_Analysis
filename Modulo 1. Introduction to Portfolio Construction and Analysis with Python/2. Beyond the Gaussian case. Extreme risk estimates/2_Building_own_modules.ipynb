# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Construcción-de-módulos" data-toc-modified-id="Construcción-de-módulos-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Construcción de módulos</a></span></li><li><span><a href="#Librerías" data-toc-modified-id="Librerías-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Librerías</a></span></li><li><span><a href="#Prácticas" data-toc-modified-id="Prácticas-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Prácticas</a></span><ul class="toc-item"><li><span><a href="#Ejemplo-1---hello.py" data-toc-modified-id="Ejemplo-1---hello.py-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Ejemplo 1 - hello.py</a></span></li><li><span><a href="#Cargar-datos" data-toc-modified-id="Cargar-datos-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Cargar datos</a></span></li><li><span><a href="#Calcular-drawdowns" data-toc-modified-id="Calcular-drawdowns-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Calcular drawdowns</a></span></li><li><span><a href="#Visualización-completa" data-toc-modified-id="Visualización-completa-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Visualización completa</a></span></li><li><span><a href="#Visualización-de-un-tramo-temporal" data-toc-modified-id="Visualización-de-un-tramo-temporal-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Visualización de un tramo temporal</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Construcción de módulos
#
# Un módulo en Python es un archivo con código python al que se puede acceder y ejecutar importando el módulo. Cuando se importa un módulo, se accede al archivo para leer el código que contiene a través de un alias (opcional).

# %% [markdown]
# <hr style="height:5px;border-width:0;color:orange;background-color:orange">

# %% [markdown]
# ## Librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot
from plotly.subplots import make_subplots
import warnings
import numpy as np


# Configuración de librerías
init_notebook_mode(connected=True)  
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# <hr style="height:5px;border-width:0;color:orange;background-color:orange">

# %% [markdown]
# ## Prácticas

# %% [markdown]
# ### Ejemplo 1 - hello.py

# %%
import modules.hello as h

# %%
h.message1
# Out:
# 'Hello Sergio'

# %% [markdown]
# Ahora, cambiamos el código de hello.py añadiendo un segundo mensaje.
#
# ```python
# message2 = '¿Como estas?'
# ```

# %%
import modules.hello as h
h.message2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-be0f7d0b4b20> in <module>
#       1 import modules.hello as h
# ----> 2 h.message2
#
# AttributeError: module 'modules.hello' has no attribute 'message2'

# %% [markdown]
# ¿Qué ha fallado?
#
# Dado que el contenido de los módulos no suele cambiar mucho (excepto durante el desarrollo del módulo) Python es inteligente a la hora de importar módulos y una vez que se importa un módulo, no se molesta en reimportarlo. Normalmente, esto es lo que quieres, pero en nuestro caso, cuando estamos desarrollando el módulo, queremos forzar que el módulo se recargue automáticamente cada vez que cambie.
#
# Afortunadamente, hay una secuencia de comandos _mágica_ que hace exactamente eso. Primero, tenemos que cargar una extensión llamada `autoreload` ejecutando el _comando mágico_ `%load_ext autoreload`. Una vez cargada esa extensión, ahora tenemos acceso a un nuevo _comando mágico_ llamado `%autoreload` que admite diferentes modos de autocarga. El modo que queremos por ahora es recargar automáticamente cualquier cosa que cambie, que es el modo 2. Por lo tanto, es necesario ejecutar:
#
# ```python
# %load_ext autoreload
# %autoreload 2
# ```

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import modules.hello as h
print(h.message1)
print(h.message2)
# Out:
# Hola Sergio
# ¿Cómo estas?

# %% [markdown]
# Ahora, vamos a crear nuestro nuevo módulo, en el que nos basaremos a lo largo del curso, y poner la función drawdown que hemos creado.

# %%
from modules import edhec_risk_kit as erk

# %% [markdown]
# ### Cargar datos

# %%
df_returns = erk.get_ffme_returns(directory='../data')
df_returns.head()
# Out:
#             SmallCap  LargeCap
# 1926-07-01   -0.0145    0.0329
# 1926-08-01    0.0512    0.0370
# 1926-09-01    0.0093    0.0067
# 1926-10-01   -0.0484   -0.0243
# 1926-11-01   -0.0078    0.0270

# %% [markdown]
# ### Calcular drawdowns

# %%
df_drawdowns_sc = erk.drawdown(stock_returns=df_returns['SmallCap'], capital_inicial=1000)
df_drawdowns_sc.head()
# Out:
#             Wealth_Index  Previous_Peaks  Drawdown
# 1926-07-01    985.500000      985.500000  0.000000
# 1926-08-01   1035.957600     1035.957600  0.000000
# 1926-09-01   1045.592006     1045.592006  0.000000
# 1926-10-01    994.985353     1045.592006 -0.048400
# 1926-11-01    987.224467     1045.592006 -0.055822

# %%
df_drawdowns_lc = erk.drawdown(stock_returns=df_returns['LargeCap'], capital_inicial=1000)
df_drawdowns_lc.head()
# Out:
#             Wealth_Index  Previous_Peaks  Drawdown
# 1926-07-01   1032.900000     1032.900000    0.0000
# 1926-08-01   1071.117300     1071.117300    0.0000
# 1926-09-01   1078.293786     1078.293786    0.0000
# 1926-10-01   1052.091247     1078.293786   -0.0243
# 1926-11-01   1080.497711     1080.497711    0.0000

# %%
# Calcular Max Drawdown
sc_max_drawdown, sc_date_max_drawdown = erk.max_drawdown(df_drawdowns_sc["Drawdown"])
lc_max_drawdown, lc_date_max_drawdown = erk.max_drawdown(df_drawdowns_lc["Drawdown"])

print('Max Drawdown:')
print(f'\t- Small Cap = {sc_max_drawdown}. Date: {sc_date_max_drawdown}')
print(f'\t- Large Cap = {lc_max_drawdown}. Date: {lc_date_max_drawdown}')
# Out:
# Max Drawdown:
# 	- Small Cap = -0.8330007793945303. Date: 1932-05
# 	- Large Cap = -0.8400375277943123. Date: 1932-05

# %% [markdown]
# ### Visualización completa

# %%
erk.plot_drawdowns(df_drawdowns_sc, title='DrawDowns Small Capital')
# Out:
# <div>                            <div id="1c7054ac-fbec-49c0-a796-aaeca0d0de0a" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c7054ac-fbec-49c0-a796-aaeca0d0de0a")) {                    Plotly.newPlot(                        "1c7054ac-fbec-49c0-a796-aaeca0d0de0a",                        [{"hovertemplate": "%{y:.5f}", "line": {"color": "blue", "width": 1}, "mode": "lines", "name": "Wealth Index", "type": "scatter", "x": ["1926-07-01T00:00:00", "1926-08-01T00:00:00", "1926-09-01T00:00:00", "1926-10-01T00:00:00", "1926-11-01T00:00:00", "1926-12-01T00:00:00", "1927-01-01T00:00:00", "1927-02-01T00:00:00", "1927-03-01T00:00:00", "1927-04-01T00:00:00", "1927-05-01T00:00:00", "1927-06-01T00:00:00", "1927-07-01T00:00:00", "1927-08-01T00:00:00", "1927-09-01T00:00:00", "1927-10-01T00:00:00", "1927-11-01T00:00:00", "1927-12-01T00:00:00", "1928-01-01T00:00:00", "1928-02-01T00:00:00", "1928-03-01T00:00:00", "1928-04-01T00:00:00", "1928-05-01T00:00:00", "1928-06-01T00:00:00", "1928-07-01T00:00:00", "1928-08-01T00:00:00", "1928-09-01T00:00:00", "1928-10-01T00:00:00", "1928-11-01T00:00:00", "1928-12-01T00:00:00", "1929-01-01T00:00:00", "1929-02-01T00:00:00", "1929-03-01T00:00:00", "1929-04-01T00:00:00", "1929-05-01T00:00:00", "1929-06-01T00:00:00", "1929-07-01T00:00:00", "1929-08-01T00:00:00", "1929-09-01T00:00:00", "1929-10-01T00:00:00", "1929-11-01T00:00:00", "1929-12-01T00:00:00", "1930-01-01T00:00:00", "1930-02-01T00:00:00", "1930-03-01T00:00:00", "1930-04-01T00:00:00", "1930-05-01T00:00:00", "1930-06-01T00:00:00", "1930-07-01T00:00:00", "1930-08-01T00:00:00", "1930-09-01T00:00:00", "1930-10-01T00:00:00", "1930-11-01T00:00:00", "1930-12-01T00:00:00", "1931-01-01T00:00:00", "1931-02-01T00:00:00", "1931-03-01T00:00:00", "1931-04-01T00:00:00", "1931-05-01T00:00:00", "1931-06-01T00:00:00", "1931-07-01T00:00:00", "1931-08-01T00:00:00", "1931-09-01T00:00:00", "1931-10-01T00:00:00", "1931-11-01T00:00:00", "1931-12-01T00:00:00", "1932-01-01T00:00:00", "1932-02-01T00:00:00", "1932-03-01T00:00:00", "1932-04-01T00:00:00", "1932-05-01T00:00:00", "1932-06-01T00:00:00", "1932-07-01T00:00:00", "1932-08-01T00:00:00", "1932-09-01T00:00:00", "1932-10-01T00:00:00", "1932-11-01T00:00:00", "1932-12-01T00:00:00", "1933-01-01T00:00:00", "1933-02-01T00:00:00", "1933-03-01T00:00:00", "1933-04-01T00:00:00", "1933-05-01T00:00:00", "1933-06-01T00:00:00", "1933-07-01T00:00:00", "1933-08-01T00:00:00", "1933-09-01T00:00:00", "1933-10-01T00:00:00", "1933-11-01T00:00:00", "1933-12-01T00:00:00", "1934-01-01T00:00:00", "1934-02-01T00:00:00", "1934-03-01T00:00:00", "1934-04-01T00:00:00", "1934-05-01T00:00:00", "1934-06-01T00:00:00", "1934-07-01T00:00:00", "1934-08-01T00:00:00", "1934-09-01T00:00:00", "1934-10-01T00:00:00", "1934-11-01T00:00:00", "1934-12-01T00:00:00", "1935-01-01T00:00:00", "1935-02-01T00:00:00", "1935-03-01T00:00:00", "1935-04-01T00:00:00", "1935-05-01T00:00:00", "1935-06-01T00:00:00", "1935-07-01T00:00:00", "1935-08-01T00:00:00", "1935-09-01T00:00:00", "1935-10-01T00:00:00", "1935-11-01T00:00:00", "1935-12-01T00:00:00", "1936-01-01T00:00:00", "1936-02-01T00:00:00", "1936-03-01T00:00:00", "1936-04-01T00:00:00", "1936-05-01T00:00:00", "1936-06-01T00:00:00", "1936-07-01T00:00:00", "1936-08-01T00:00:00", "1936-09-01T00:00:00", "1936-10-01T00:00:00", "1936-11-01T00:00:00", "1936-12-01T00:00:00", "1937-01-01T00:00:00", "1937-02-01T00:00:00", "1937-03-01T00:00:00", "1937-04-01T00:00:00", "1937-05-01T00:00:00", "1937-06-01T00:00:00", "1937-07-01T00:00:00", "1937-08-01T00:00:00", "1937-09-01T00:00:00", "1937-10-01T00:00:00", "1937-11-01T00:00:00", "1937-12-01T00:00:00", "1938-01-01T00:00:00", "1938-02-01T00:00:00", "1938-03-01T00:00:00", "1938-04-01T00:00:00", "1938-05-01T00:00:00", "1938-06-01T00:00:00", "1938-07-01T00:00:00 ...

# %%
erk.plot_drawdowns(df_drawdowns_lc, title='DrawDowns Large Capital')
# Out:
# <div>                            <div id="97cfe288-e6f1-41bc-af64-b15c2838b15a" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97cfe288-e6f1-41bc-af64-b15c2838b15a")) {                    Plotly.newPlot(                        "97cfe288-e6f1-41bc-af64-b15c2838b15a",                        [{"hovertemplate": "%{y:.5f}", "line": {"color": "blue", "width": 1}, "mode": "lines", "name": "Wealth Index", "type": "scatter", "x": ["1926-07-01T00:00:00", "1926-08-01T00:00:00", "1926-09-01T00:00:00", "1926-10-01T00:00:00", "1926-11-01T00:00:00", "1926-12-01T00:00:00", "1927-01-01T00:00:00", "1927-02-01T00:00:00", "1927-03-01T00:00:00", "1927-04-01T00:00:00", "1927-05-01T00:00:00", "1927-06-01T00:00:00", "1927-07-01T00:00:00", "1927-08-01T00:00:00", "1927-09-01T00:00:00", "1927-10-01T00:00:00", "1927-11-01T00:00:00", "1927-12-01T00:00:00", "1928-01-01T00:00:00", "1928-02-01T00:00:00", "1928-03-01T00:00:00", "1928-04-01T00:00:00", "1928-05-01T00:00:00", "1928-06-01T00:00:00", "1928-07-01T00:00:00", "1928-08-01T00:00:00", "1928-09-01T00:00:00", "1928-10-01T00:00:00", "1928-11-01T00:00:00", "1928-12-01T00:00:00", "1929-01-01T00:00:00", "1929-02-01T00:00:00", "1929-03-01T00:00:00", "1929-04-01T00:00:00", "1929-05-01T00:00:00", "1929-06-01T00:00:00", "1929-07-01T00:00:00", "1929-08-01T00:00:00", "1929-09-01T00:00:00", "1929-10-01T00:00:00", "1929-11-01T00:00:00", "1929-12-01T00:00:00", "1930-01-01T00:00:00", "1930-02-01T00:00:00", "1930-03-01T00:00:00", "1930-04-01T00:00:00", "1930-05-01T00:00:00", "1930-06-01T00:00:00", "1930-07-01T00:00:00", "1930-08-01T00:00:00", "1930-09-01T00:00:00", "1930-10-01T00:00:00", "1930-11-01T00:00:00", "1930-12-01T00:00:00", "1931-01-01T00:00:00", "1931-02-01T00:00:00", "1931-03-01T00:00:00", "1931-04-01T00:00:00", "1931-05-01T00:00:00", "1931-06-01T00:00:00", "1931-07-01T00:00:00", "1931-08-01T00:00:00", "1931-09-01T00:00:00", "1931-10-01T00:00:00", "1931-11-01T00:00:00", "1931-12-01T00:00:00", "1932-01-01T00:00:00", "1932-02-01T00:00:00", "1932-03-01T00:00:00", "1932-04-01T00:00:00", "1932-05-01T00:00:00", "1932-06-01T00:00:00", "1932-07-01T00:00:00", "1932-08-01T00:00:00", "1932-09-01T00:00:00", "1932-10-01T00:00:00", "1932-11-01T00:00:00", "1932-12-01T00:00:00", "1933-01-01T00:00:00", "1933-02-01T00:00:00", "1933-03-01T00:00:00", "1933-04-01T00:00:00", "1933-05-01T00:00:00", "1933-06-01T00:00:00", "1933-07-01T00:00:00", "1933-08-01T00:00:00", "1933-09-01T00:00:00", "1933-10-01T00:00:00", "1933-11-01T00:00:00", "1933-12-01T00:00:00", "1934-01-01T00:00:00", "1934-02-01T00:00:00", "1934-03-01T00:00:00", "1934-04-01T00:00:00", "1934-05-01T00:00:00", "1934-06-01T00:00:00", "1934-07-01T00:00:00", "1934-08-01T00:00:00", "1934-09-01T00:00:00", "1934-10-01T00:00:00", "1934-11-01T00:00:00", "1934-12-01T00:00:00", "1935-01-01T00:00:00", "1935-02-01T00:00:00", "1935-03-01T00:00:00", "1935-04-01T00:00:00", "1935-05-01T00:00:00", "1935-06-01T00:00:00", "1935-07-01T00:00:00", "1935-08-01T00:00:00", "1935-09-01T00:00:00", "1935-10-01T00:00:00", "1935-11-01T00:00:00", "1935-12-01T00:00:00", "1936-01-01T00:00:00", "1936-02-01T00:00:00", "1936-03-01T00:00:00", "1936-04-01T00:00:00", "1936-05-01T00:00:00", "1936-06-01T00:00:00", "1936-07-01T00:00:00", "1936-08-01T00:00:00", "1936-09-01T00:00:00", "1936-10-01T00:00:00", "1936-11-01T00:00:00", "1936-12-01T00:00:00", "1937-01-01T00:00:00", "1937-02-01T00:00:00", "1937-03-01T00:00:00", "1937-04-01T00:00:00", "1937-05-01T00:00:00", "1937-06-01T00:00:00", "1937-07-01T00:00:00", "1937-08-01T00:00:00", "1937-09-01T00:00:00", "1937-10-01T00:00:00", "1937-11-01T00:00:00", "1937-12-01T00:00:00", "1938-01-01T00:00:00", "1938-02-01T00:00:00", "1938-03-01T00:00:00", "1938-04-01T00:00:00", "1938-05-01T00:00:00", "1938-06-01T00:00:00", "1938-07-01T00:00:00 ...

# %% [markdown]
# ### Visualización de un tramo temporal

# %%
max_year='1950'
erk.plot_drawdowns(df_drawdowns_sc.loc[:max_year], title='DrawDowns Small Capital')
# Out:
# <div>                            <div id="9ea72147-c165-4be7-b0f7-9b3e8fef3327" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ea72147-c165-4be7-b0f7-9b3e8fef3327")) {                    Plotly.newPlot(                        "9ea72147-c165-4be7-b0f7-9b3e8fef3327",                        [{"hovertemplate": "%{y:.5f}", "line": {"color": "blue", "width": 1}, "mode": "lines", "name": "Wealth Index", "type": "scatter", "x": ["1926-07-01T00:00:00", "1926-08-01T00:00:00", "1926-09-01T00:00:00", "1926-10-01T00:00:00", "1926-11-01T00:00:00", "1926-12-01T00:00:00", "1927-01-01T00:00:00", "1927-02-01T00:00:00", "1927-03-01T00:00:00", "1927-04-01T00:00:00", "1927-05-01T00:00:00", "1927-06-01T00:00:00", "1927-07-01T00:00:00", "1927-08-01T00:00:00", "1927-09-01T00:00:00", "1927-10-01T00:00:00", "1927-11-01T00:00:00", "1927-12-01T00:00:00", "1928-01-01T00:00:00", "1928-02-01T00:00:00", "1928-03-01T00:00:00", "1928-04-01T00:00:00", "1928-05-01T00:00:00", "1928-06-01T00:00:00", "1928-07-01T00:00:00", "1928-08-01T00:00:00", "1928-09-01T00:00:00", "1928-10-01T00:00:00", "1928-11-01T00:00:00", "1928-12-01T00:00:00", "1929-01-01T00:00:00", "1929-02-01T00:00:00", "1929-03-01T00:00:00", "1929-04-01T00:00:00", "1929-05-01T00:00:00", "1929-06-01T00:00:00", "1929-07-01T00:00:00", "1929-08-01T00:00:00", "1929-09-01T00:00:00", "1929-10-01T00:00:00", "1929-11-01T00:00:00", "1929-12-01T00:00:00", "1930-01-01T00:00:00", "1930-02-01T00:00:00", "1930-03-01T00:00:00", "1930-04-01T00:00:00", "1930-05-01T00:00:00", "1930-06-01T00:00:00", "1930-07-01T00:00:00", "1930-08-01T00:00:00", "1930-09-01T00:00:00", "1930-10-01T00:00:00", "1930-11-01T00:00:00", "1930-12-01T00:00:00", "1931-01-01T00:00:00", "1931-02-01T00:00:00", "1931-03-01T00:00:00", "1931-04-01T00:00:00", "1931-05-01T00:00:00", "1931-06-01T00:00:00", "1931-07-01T00:00:00", "1931-08-01T00:00:00", "1931-09-01T00:00:00", "1931-10-01T00:00:00", "1931-11-01T00:00:00", "1931-12-01T00:00:00", "1932-01-01T00:00:00", "1932-02-01T00:00:00", "1932-03-01T00:00:00", "1932-04-01T00:00:00", "1932-05-01T00:00:00", "1932-06-01T00:00:00", "1932-07-01T00:00:00", "1932-08-01T00:00:00", "1932-09-01T00:00:00", "1932-10-01T00:00:00", "1932-11-01T00:00:00", "1932-12-01T00:00:00", "1933-01-01T00:00:00", "1933-02-01T00:00:00", "1933-03-01T00:00:00", "1933-04-01T00:00:00", "1933-05-01T00:00:00", "1933-06-01T00:00:00", "1933-07-01T00:00:00", "1933-08-01T00:00:00", "1933-09-01T00:00:00", "1933-10-01T00:00:00", "1933-11-01T00:00:00", "1933-12-01T00:00:00", "1934-01-01T00:00:00", "1934-02-01T00:00:00", "1934-03-01T00:00:00", "1934-04-01T00:00:00", "1934-05-01T00:00:00", "1934-06-01T00:00:00", "1934-07-01T00:00:00", "1934-08-01T00:00:00", "1934-09-01T00:00:00", "1934-10-01T00:00:00", "1934-11-01T00:00:00", "1934-12-01T00:00:00", "1935-01-01T00:00:00", "1935-02-01T00:00:00", "1935-03-01T00:00:00", "1935-04-01T00:00:00", "1935-05-01T00:00:00", "1935-06-01T00:00:00", "1935-07-01T00:00:00", "1935-08-01T00:00:00", "1935-09-01T00:00:00", "1935-10-01T00:00:00", "1935-11-01T00:00:00", "1935-12-01T00:00:00", "1936-01-01T00:00:00", "1936-02-01T00:00:00", "1936-03-01T00:00:00", "1936-04-01T00:00:00", "1936-05-01T00:00:00", "1936-06-01T00:00:00", "1936-07-01T00:00:00", "1936-08-01T00:00:00", "1936-09-01T00:00:00", "1936-10-01T00:00:00", "1936-11-01T00:00:00", "1936-12-01T00:00:00", "1937-01-01T00:00:00", "1937-02-01T00:00:00", "1937-03-01T00:00:00", "1937-04-01T00:00:00", "1937-05-01T00:00:00", "1937-06-01T00:00:00", "1937-07-01T00:00:00", "1937-08-01T00:00:00", "1937-09-01T00:00:00", "1937-10-01T00:00:00", "1937-11-01T00:00:00", "1937-12-01T00:00:00", "1938-01-01T00:00:00", "1938-02-01T00:00:00", "1938-03-01T00:00:00", "1938-04-01T00:00:00", "1938-05-01T00:00:00", "1938-06-01T00:00:00", "1938-07-01T00:00:00 ...

# %%
max_year='1950'
erk.plot_drawdowns(df_drawdowns_lc.loc[:max_year], title='DrawDowns Large Capital')
# Out:
# <div>                            <div id="f2f02535-7737-424b-94dc-e0e9897d7b2a" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f2f02535-7737-424b-94dc-e0e9897d7b2a")) {                    Plotly.newPlot(                        "f2f02535-7737-424b-94dc-e0e9897d7b2a",                        [{"hovertemplate": "%{y:.5f}", "line": {"color": "blue", "width": 1}, "mode": "lines", "name": "Wealth Index", "type": "scatter", "x": ["1926-07-01T00:00:00", "1926-08-01T00:00:00", "1926-09-01T00:00:00", "1926-10-01T00:00:00", "1926-11-01T00:00:00", "1926-12-01T00:00:00", "1927-01-01T00:00:00", "1927-02-01T00:00:00", "1927-03-01T00:00:00", "1927-04-01T00:00:00", "1927-05-01T00:00:00", "1927-06-01T00:00:00", "1927-07-01T00:00:00", "1927-08-01T00:00:00", "1927-09-01T00:00:00", "1927-10-01T00:00:00", "1927-11-01T00:00:00", "1927-12-01T00:00:00", "1928-01-01T00:00:00", "1928-02-01T00:00:00", "1928-03-01T00:00:00", "1928-04-01T00:00:00", "1928-05-01T00:00:00", "1928-06-01T00:00:00", "1928-07-01T00:00:00", "1928-08-01T00:00:00", "1928-09-01T00:00:00", "1928-10-01T00:00:00", "1928-11-01T00:00:00", "1928-12-01T00:00:00", "1929-01-01T00:00:00", "1929-02-01T00:00:00", "1929-03-01T00:00:00", "1929-04-01T00:00:00", "1929-05-01T00:00:00", "1929-06-01T00:00:00", "1929-07-01T00:00:00", "1929-08-01T00:00:00", "1929-09-01T00:00:00", "1929-10-01T00:00:00", "1929-11-01T00:00:00", "1929-12-01T00:00:00", "1930-01-01T00:00:00", "1930-02-01T00:00:00", "1930-03-01T00:00:00", "1930-04-01T00:00:00", "1930-05-01T00:00:00", "1930-06-01T00:00:00", "1930-07-01T00:00:00", "1930-08-01T00:00:00", "1930-09-01T00:00:00", "1930-10-01T00:00:00", "1930-11-01T00:00:00", "1930-12-01T00:00:00", "1931-01-01T00:00:00", "1931-02-01T00:00:00", "1931-03-01T00:00:00", "1931-04-01T00:00:00", "1931-05-01T00:00:00", "1931-06-01T00:00:00", "1931-07-01T00:00:00", "1931-08-01T00:00:00", "1931-09-01T00:00:00", "1931-10-01T00:00:00", "1931-11-01T00:00:00", "1931-12-01T00:00:00", "1932-01-01T00:00:00", "1932-02-01T00:00:00", "1932-03-01T00:00:00", "1932-04-01T00:00:00", "1932-05-01T00:00:00", "1932-06-01T00:00:00", "1932-07-01T00:00:00", "1932-08-01T00:00:00", "1932-09-01T00:00:00", "1932-10-01T00:00:00", "1932-11-01T00:00:00", "1932-12-01T00:00:00", "1933-01-01T00:00:00", "1933-02-01T00:00:00", "1933-03-01T00:00:00", "1933-04-01T00:00:00", "1933-05-01T00:00:00", "1933-06-01T00:00:00", "1933-07-01T00:00:00", "1933-08-01T00:00:00", "1933-09-01T00:00:00", "1933-10-01T00:00:00", "1933-11-01T00:00:00", "1933-12-01T00:00:00", "1934-01-01T00:00:00", "1934-02-01T00:00:00", "1934-03-01T00:00:00", "1934-04-01T00:00:00", "1934-05-01T00:00:00", "1934-06-01T00:00:00", "1934-07-01T00:00:00", "1934-08-01T00:00:00", "1934-09-01T00:00:00", "1934-10-01T00:00:00", "1934-11-01T00:00:00", "1934-12-01T00:00:00", "1935-01-01T00:00:00", "1935-02-01T00:00:00", "1935-03-01T00:00:00", "1935-04-01T00:00:00", "1935-05-01T00:00:00", "1935-06-01T00:00:00", "1935-07-01T00:00:00", "1935-08-01T00:00:00", "1935-09-01T00:00:00", "1935-10-01T00:00:00", "1935-11-01T00:00:00", "1935-12-01T00:00:00", "1936-01-01T00:00:00", "1936-02-01T00:00:00", "1936-03-01T00:00:00", "1936-04-01T00:00:00", "1936-05-01T00:00:00", "1936-06-01T00:00:00", "1936-07-01T00:00:00", "1936-08-01T00:00:00", "1936-09-01T00:00:00", "1936-10-01T00:00:00", "1936-11-01T00:00:00", "1936-12-01T00:00:00", "1937-01-01T00:00:00", "1937-02-01T00:00:00", "1937-03-01T00:00:00", "1937-04-01T00:00:00", "1937-05-01T00:00:00", "1937-06-01T00:00:00", "1937-07-01T00:00:00", "1937-08-01T00:00:00", "1937-09-01T00:00:00", "1937-10-01T00:00:00", "1937-11-01T00:00:00", "1937-12-01T00:00:00", "1938-01-01T00:00:00", "1938-02-01T00:00:00", "1938-03-01T00:00:00", "1938-04-01T00:00:00", "1938-05-01T00:00:00", "1938-06-01T00:00:00", "1938-07-01T00:00:00 ...
